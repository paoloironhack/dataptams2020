# %%
input_valid = 0

while input_valid == 0:
    c = input("Enter a four digit code: ")
    if len(c) != 4:
        print("Your code must be 4 digits")
    elif ord(c[0]) <= 47 or ord(c[0]) >= 58:
        print('Your code can only consist of numbers')
    elif ord(c[1]) <= 47 or ord(c[1]) >= 58:
        print('Your code can only consist of numbers')
    elif ord(c[2]) <= 47 or ord(c[2]) >= 58:
        print('Your code can only consist of numbers')
    elif ord(c[3]) <= 47 or ord(c[3]) >= 58:
        print('Your code can only consist of numbers')
    else:
        input_valid += 1

num_guesses = 0


while num_guesses < 4:
    g = input("Guess number " + str(num_guesses + 1) + ":")

    if g == c:
        print("You're a Mastermind!")    
    

    right = []
    wrong = []
    randw = []

    for x in g[0]:
        if g[0] == c[0]:
            right.append(c[0])
        elif g[0] != c[0]:
            wrong.append('X')

    for x in g[1]:
        if g[1] == c[1]:
            right.append(c[1])
        elif g[1] != c[1]:
            wrong.append('X')

    for x in g[2]:
        if g[2] == c[2]:
            right.append(c[2])
        elif g[2] != c[2]:
            wrong.append('X')

    for x in g[3]:
        if g[3] == c[3]:
            right.append(c[3])
        elif g[3] != c[3]:
            wrong.append('X') 

    randw.append(right)
    randw.append(wrong)
    feedback = [j for i in randw for j in i]

    if len(right) > 0:
        print('Not quite but you did get these right:', right)
    else:
        print("You didn't get any right")
    num_guesses += 1

print('You lose')

# %%
input_valid = 0

while input_valid == 0:
    c = input("Enter a four digit code: ")
    if len(c) != 4:
        print("Your code must be 4 digits")
    elif ord(c[0]) <= 47 or ord(c[0]) >= 58:
        print('Your code can only consist of numbers')
    elif ord(c[1]) <= 47 or ord(c[1]) >= 58:
        print('Your code can only consist of numbers')
    elif ord(c[2]) <= 47 or ord(c[2]) >= 58:
        print('Your code can only consist of numbers')
    elif ord(c[3]) <= 47 or ord(c[3]) >= 58:
        print('Your code can only consist of numbers')
    else:
        input_valid += 1

num_guesses = 0
while num_guesses < 4:
    g = input("Guess number " + str(num_guesses + 1) + ":")
    if g == c:
        print("You're a Mastermind!") 
        break
    
    right = []
    wrong = []
    randw = []

    for x in g[0]:
        if g[0] == c[0]:
            right.append(c[0])
        elif g[0] != c[0]:
            wrong.append('X')

    for x in g[1]:
        if g[1] == c[1]:
            right.append(c[1])
        elif g[1] != c[1]:
            wrong.append('X')

    for x in g[2]:
        if g[2] == c[2]:
            right.append(c[2])
        elif g[2] != c[2]:
            wrong.append('X')

    for x in g[3]:
        if g[3] == c[3]:
            right.append(c[3])
        elif g[3] != c[3]:
            wrong.append('X') 

    randw.append(right)
    randw.append(wrong)
    feedback = [j for i in randw for j in i]

    if len(right) > 0:
        print('Not quite but you did get these right:', right)
    else:
        print("You didn't get any right")
    num_guesses += 1
#print('You lose')
if g!=c:
    print('you lose')
