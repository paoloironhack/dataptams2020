# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./data/nutrition.csv')
nutrition.drop(columns=['Unnamed: 0'], inplace=True)
#nutrition_2=nutrition.columns
#nutrition[nutrition_2]=nutrition[nutrition_2].replace({'g':''}, regex=True)
data
